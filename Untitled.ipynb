# %%
def plotSurv(tmp1, tmp2):
    #tmp1 = f'traindf.{word1}'
    #tmp2 = f'traindf.{word2}'
    pd.crosstab(traindf.tmp1.values, traindf.tmp2.values).plot(kind='bar')

# %%
import matplotlib.pyplot as plt
plt.plot([1, 2, 3, 4],[1, 3, 5, 7])
plt.ylabel('some numbers')
plt.show()
